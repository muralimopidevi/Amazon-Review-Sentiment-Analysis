# %% [markdown]
# ## Amazon Review Cell Phone and Accessories

# %% [markdown]
# ## Dataset Info , Check the below link.
#
# selected dataset is --> Cell Phone and Accessories.
# https://nijianmo.github.io/amazon/index.html

# %% [markdown]
# ## Databricks File System(DBFS) Connection.

# %%
# File location and type
file_location = "/FileStore/tables/Cell_Phones_and_Accessories_5.json"
file_type = "json"

# Json options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for json files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

#diaplaying dataframe 'df'
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Printing the Schema of a Dataframe(df)

# %%
# Displaying datatypes in a table. 
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- asin: string (nullable = true)
# -- helpful: array (nullable = true)
#     |-- element: long (containsNull = true)
# -- overall: double (nullable = true)
# -- reviewText: string (nullable = true)
# -- reviewTime: string (nullable = true)
# -- reviewerID: string (nullable = true)
# -- reviewerName: string (nullable = true)
# -- summary: string (nullable = true)
# -- unixReviewTime: long (nullable = true)
#
# </div>

# %% [markdown]
# ## Importing the Libraries

# %%
# Import the libraries 
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re 
import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/nltk/decorators.py:68: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   regargs, varargs, varkwargs, defaults, formatvalue=lambda value: &#34;&#34;
# </div>

# %% [markdown]
# ## Creating a Temporary view

# %%
# Creating a view or table for a dataframe df.
temp_table_name = "temptable"
df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Using SQL to select all columns in temp view(table) as 'temptable'

# %%
# %sql
select * from temptable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Top 10 users who Rated Most

# %%
# %sql
select count(reviewerID), reviewerID from temptable Group By reviewerID ORDER BY COUNT(reviewerID) DESC LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(reviewerID)</th><th>reviewerID</th></tr></thead><tbody><tr><td>152</td><td>A2NYK9KWFMJV4Y</td></tr><tr><td>138</td><td>A1EVV74UQYVKRY</td></tr><tr><td>138</td><td>A22CW0ZHY3NJH8</td></tr><tr><td>134</td><td>A1ODOGXEYECQQ8</td></tr><tr><td>132</td><td>A2NOW4U7W3F7RI</td></tr><tr><td>124</td><td>A36K2N527TXXJN</td></tr><tr><td>114</td><td>A1UQBFCERIP7VJ</td></tr><tr><td>109</td><td>A18U49406IPPIJ</td></tr><tr><td>109</td><td>A1E1LEVQ9VQNK</td></tr><tr><td>107</td><td>AYB4ELCS5AM8P</td></tr></tbody></table></div>

# %% [markdown]
# ## count of in overall

# %%
# %sql
select count(overall), overall from temptable Group By overall ORDER BY COUNT(overall) DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(overall)</th><th>overall</th></tr></thead><tbody><tr><td>108664</td><td>5.0</td></tr><tr><td>39993</td><td>4.0</td></tr><tr><td>21439</td><td>3.0</td></tr><tr><td>13279</td><td>1.0</td></tr><tr><td>11064</td><td>2.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Reviewed as 'Good' with count of overall(ratings)

# %%
# %sql
SELECT count(overall), overall FROM temptable WHERE reviewText LIKE '%good%' GROUP BY overall ORDER BY overall
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(overall)</th><th>overall</th></tr></thead><tbody><tr><td>1757</td><td>1.0</td></tr><tr><td>2177</td><td>2.0</td></tr><tr><td>5066</td><td>3.0</td></tr><tr><td>11525</td><td>4.0</td></tr><tr><td>20685</td><td>5.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Reviewed as 'Good' with count of overall(ratings)

# %%
# %sql
SELECT count(overall), overall FROM temptable WHERE summary LIKE '%good%' GROUP BY overall ORDER BY overall
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(overall)</th><th>overall</th></tr></thead><tbody><tr><td>363</td><td>1.0</td></tr><tr><td>459</td><td>2.0</td></tr><tr><td>1113</td><td>3.0</td></tr><tr><td>2971</td><td>4.0</td></tr><tr><td>3667</td><td>5.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Reviewed as 'bad' with count of overall(ratings)

# %%
# %sql
SELECT count(overall), overall FROM temptable WHERE reviewText LIKE '%bad%' GROUP BY overall ORDER BY overall
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(overall)</th><th>overall</th></tr></thead><tbody><tr><td>897</td><td>1.0</td></tr><tr><td>747</td><td>2.0</td></tr><tr><td>1470</td><td>3.0</td></tr><tr><td>1929</td><td>4.0</td></tr><tr><td>2623</td><td>5.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Reviewed as 'bad' with count of overall(ratings)

# %%
# %sql
SELECT count(overall), overall FROM temptable WHERE summary LIKE '%bad%' GROUP BY overall ORDER BY overall
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(overall)</th><th>overall</th></tr></thead><tbody><tr><td>172</td><td>1.0</td></tr><tr><td>114</td><td>2.0</td></tr><tr><td>403</td><td>3.0</td></tr><tr><td>411</td><td>4.0</td></tr><tr><td>104</td><td>5.0</td></tr></tbody></table></div>

# %%
from pyspark.ml.feature import RegexTokenizer

tokenizer = (RegexTokenizer()
            .setInputCol("reviewText")
            .setOutputCol("tokens")
            .setPattern("\\W+"))

tokenizedDF = tokenizer.transform(df)
display(tokenizedDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.ml.feature import StopWordsRemover

remover = (StopWordsRemover()
          .setInputCol("tokens")
          .setOutputCol("stopWordFree"))

removedStopWordsDF = remover.transform(tokenizedDF)
display(removedStopWordsDF.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.ml.feature import CountVectorizer

counts = (CountVectorizer()
          .setInputCol("stopWordFree")
          .setOutputCol("features")
          .setVocabSize(1000))

countModel = counts.fit(removedStopWordsDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.feature import Binarizer

binarizer = Binarizer()  \
  .setInputCol("overall") \
  .setOutputCol("label") \
  .setThreshold(3.5)

print("Binarizer output with Threshold = %f" % binarizer.getThreshold())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Binarizer output with Threshold = 3.500000
# </div>

# %%
(testDF, trainingDF) = df.select("overall","reviewText").na.drop().randomSplit((0.20, 0.80), seed=123)
testDF.cache()
trainingDF.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: DataFrame[overall: double, reviewText: string]</div>

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline

lr = LogisticRegression()

p = Pipeline().setStages([tokenizer, remover, counts, binarizer, lr])
model = p.fit(trainingDF)
model.stages[-1].summary.areaUnderROC

result = model.transform(testDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

evaluator = BinaryClassificationEvaluator()
print ("AUC: %(result)s" % {"result": evaluator.evaluate(result)})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">AUC: 0.8668562470518529
# </div>
